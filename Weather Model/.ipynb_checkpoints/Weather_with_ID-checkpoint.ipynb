# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import explained_variance_score,     mean_absolute_error,     median_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Modified2.csv').set_index('id')
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# meantempm        1673.0    18.351464  11.292208  -17.0    12.0    20.0
# maxtempm         1673.0    24.768081  11.624354  -12.0    19.0    27.0
# mintempm         1673.0    11.768679  11.500402  -27.0     4.0    13.0
# meantempm_1      1673.0    18.344889  11.311065  -17.0    12.0    20.0
# meantempm_2      1673.0    18.338314  11.333106  -17.0    12.0    20.0
# meantempm_3      1673.0    18.329946  11.353494  -17.0    12.0    20.0
# meandewptm_1     1673.0     8.684997  10.251648  -22.0     2.0     9.0
# meandewptm_2     1673.0     8.673042  10.260604  -22.0     2.0     9.0
# meandewptm_3     1673.0     8.654513  10.273657  -22.0     2.0     9.0
# meanpressurem_1  1673.0  1013.456629   7.863256  989.0  1008.0  1014.0
# meanpressurem_2  1673.0  1013.453461   7.867290  989.0  1008.0  1014.0
# meanpressurem_3  1673.0  1013.453742   7.873048  989.0  1008.0  1014.0
# maxhumidity_1    1673.0    79.751943  18.728705   15.0    70.0    86.0
# maxhumidity_2    1673.0    79.741184  18.755556   15.0    70.0    86.0
# maxhumidity_3    1673.0    79.725643  18.771496   15.0    70.0    86.0
# minhumidity_1    1673.0    36.648536  20.875963    4.0    18.0    37.0
# minhumidity_2    1673.0    36.646145  20.873516    4.0    18.0    37.0
# minhumidity_3    1673.0    36.622236  20.840521    4.0    18.0    37.0
# maxtempm_1       1673.0    24.760311  11.641035  -12.0    19.0    27.0
# maxtempm_2       1673.0    24.754931  11.661020  -12.0    19.0    27.0
# maxtempm_3       1673.0    24.751345  11.679905  -12.0    19.0    27.0
# mintempm_1       1673.0    11.762702  11.522674  -27.0     4.0    13.0
# mintempm_2       1673.0    11.754931  11.543643  -27.0     4.0    13.0
# mintempm_3       1673.0    11.742977  11.563262  -27.0     4.0    13.0
# maxdewptm_1      1673.0    12.124925   9.684462  -18.0     6.0    13.0
# maxdewptm_2      1673.0    12.114764   9.694187  -18.0     6.0    13.0
# maxdewptm_3      1673.0    12.102809   9.702708  -18.0     6.0    13.0
# mindewptm_1      1673.0     4.965929  11.599813  -94.0    -3.0     5.0
# mindewptm_2      1673.0     4.951584  11.608318  -94.0    -3.0     5.0
# mindewptm_3      1673.0     4.927675  11.625029  -94.0    -3.0     5.0
# maxpressurem_1   1673.0  1016.815302   8.198492  993.0  1011.0  1017.0
# maxpressurem_2   1673.0  1016.812313   8.203420  993.0  1011.0  1017.0
# maxpressurem_3   1673.0  1016.813509   8.207966  993.0  1011.0  1017.0
# minpressurem_1   1673.0  1009.473401   8.338067  956.0  1003.0  1010.0
# minpressurem_2   1673.0  1009.469815   8.341569  956.0  1003.0  1010.0
# minpressurem_3   1673.0  1009.468022   8.348514  956.0  1003.0  1010.0
# precipm_1        1673.0     2.050687   7.394311    0.0     0.0     0.0
# precipm_2        1673.0     2.050687   7.394311    0.0     0.0     0.0
# precipm_3        1673.0     2.038691   7.381329    0.0     0.0     0.0
#
#                      75%      max
# meantempm          27.00    38.00
# maxtempm           33.00    46.00
# mintempm           21.00    32.00
# meantempm_1        27.00    38.00
# meantempm_2        27.00    38.00
# meantempm_3        27.00    38.00
# meandewptm_1       17.00    26.00
# meandewptm_2       17.00    26.00
# meandewptm_3       17.00    26.00
# meanpressurem_1  1018.17  1040.00
# meanpressurem_2  1018.17  1040.00
# meanpressurem_3  1018.24  1040.00
# maxhumidity_1      93.00   100.00
# maxhumidity_2      93.00   100.00
# maxhumidity_3      93.00   100.00
# minhumidity_1      52.00    92.00
# minhumidity_2      52.00    92.00
# minhumidity_3      52.00    92.00
# maxtempm_1         33.00    46.00
# maxtempm_2         33.00    46.00
# maxtempm_3         33.00    46.00
# mintempm_1         21.00    32.00
# mintempm_2         21.00    32.00
# mintempm_3         21.00    32.00
# maxdewptm_1        20.00    29.00
# maxdewptm_2        20.00    29.00
# maxdewptm_3        20.00    29.00
# mindewptm_1        14.00    25.00
# mindewptm_2        14.00    25.00
# mindewptm_3        14.00    25.00
# maxpressurem_1   1021.00  1055.00
# maxpressurem_2   1021.00  1055.00
# maxpressurem_3   1021.00  1055.00
# minpressurem_1   1015.00  1035.00
# minpressurem_2   1015.00  1035.00
# minpressurem_3   1015.00  1035.00
# precipm_1           0.00    95.76
# precipm_2           0.00    95.76
# precipm_3           0.00    95.76

# %%
df = df.drop(['mintempm', 'maxtempm'], axis=1)
X = df[[col for col in df.columns if col != 'meantempm']]
y = df['meantempm']

# %%
X_train, X_tmp, y_train, y_tmp = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
X_test, X_val, y_test, y_val = train_test_split(X_tmp, y_tmp, test_size=0.5, random_state=23)

X_train.shape, X_test.shape, X_val.shape
print("Training instances   {}, Training features   {}".format(X_train.shape[0], X_train.shape[1]))
print("Validation instances {}, Validation features {}".format(X_val.shape[0], X_val.shape[1]))
print("Testing instances    {}, Testing features    {}".format(X_test.shape[0], X_test.shape[1]))
# Out:
# Training instances   1338, Training features   36
# Validation instances 168, Validation features 36
# Testing instances    167, Testing features    36

# %%
feature_cols = [tf.feature_column.numeric_column(col) for col in X.columns]

# %%
regressor = tf.estimator.DNNRegressor(feature_columns=feature_cols,
                                      hidden_units=[50, 50],
                                      model_dir='tf_wx_model')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'tf_wx_model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000008C05A8A988>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def wx_input_fn(X, y=None, num_epochs=None, shuffle=True, batch_size=400):
    return tf.compat.v1.estimator.inputs.pandas_input_fn(x=X,
                                               y=y,
                                               num_epochs=num_epochs,
                                               shuffle=shuffle,
                                               batch_size=batch_size)

# %%
evaluations = []
STEPS = 400
for i in range(100):
    regressor.train(input_fn=wx_input_fn(X_train, y=y_train), steps=STEPS)
    evaluation = regressor.evaluate(input_fn=wx_input_fn(X_val, y_val,
                                                         num_epochs=1,
                                                         shuffle=False),
                                    steps=1)
    evaluations.append(regressor.evaluate(input_fn=wx_input_fn(X_val,
                                                               y_val,
                                                               num_epochs=1,
                                                               shuffle=False)))
# Out:
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_estimator\python\estimator\head\regression_head.py:156: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\optimizer_v2\adagrad.py:108: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 221302.36, step = 0
# INFO:tensorflow:global_step/sec: 46.2233
# INFO:tensorflow:loss = 172.50519, step = 100 (2.165 sec)
# INFO:tensorflow:global_step/sec: 57.1732
# INFO:tensorflow:loss = 148.43584, step = 200 (1.733 sec)
# INFO:tensorflow:global_step/sec: 60.081
# INFO:tensorflow:loss = 132.82892, step = 300 (1.664 sec)
# INFO:tensorflow:Saving checkpoints for 400 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 114.939064.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:41:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:41:58
# INFO:tensorflow:Saving dict for global step 400: average_loss = 139.82773, global_step = 400, label/mean = 17.910715, loss = 139.82773, prediction/mean = 18.828098
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: tf_wx_model\model.ckpt-400
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:02
# INFO:tensorflow:Saving dict for global step 400: average_loss = 139.82773, global_step = 400, label/mean = 17.910715, loss = 139.82773, prediction/mean = 18.828098
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: tf_wx_model\model.ckpt-400
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-400
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 400 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 122.23451, step = 400
# INFO:tensorflow:global_step/sec: 45.2985
# INFO:tensorflow:loss = 115.26387, step = 500 (2.210 sec)
# INFO:tensorflow:global_step/sec: 60.1178
# INFO:tensorflow:loss = 102.50663, step = 600 (1.663 sec)
# INFO:tensorflow:global_step/sec: 59.059
# INFO:tensorflow:loss = 102.8342, step = 700 (1.693 sec)
# INFO:tensorflow:Saving checkpoints for 800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 92.12002.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:18
# INFO:tensorflow:Saving dict for global step 800: average_loss = 102.20321, global_step = 800, label/mean = 17.910715, loss = 102.20321, prediction/mean = 18.714432
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: tf_wx_model\model.ckpt-800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:21
# INFO:tensorflow:Saving dict for global step 800: average_loss = 102.20321, global_step = 800, label/mean = 17.910715, loss = 102.20321, prediction/mean = 18.714432
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: tf_wx_model\model.ckpt-800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 84.51377, step = 800
# INFO:tensorflow:global_step/sec: 50.4582
# INFO:tensorflow:loss = 88.63449, step = 900 (1.982 sec)
# INFO:tensorflow:global_step/sec: 59.3203
# INFO:tensorflow:loss = 71.477234, step = 1000 (1.687 sec)
# INFO:tensorflow:global_step/sec: 58.7036
# INFO:tensorflow:loss = 68.69109, step = 1100 (1.701 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 73.43912.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:36
# INFO:tensorflow:Saving dict for global step 1200: average_loss = 77.687584, global_step = 1200, label/mean = 17.910715, loss = 77.687584, prediction/mean = 18.665035
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: tf_wx_model\model.ckpt-1200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:39
# INFO:tensorflow:Saving dict for global step 1200: average_loss = 77.687584, global_step = 1200, label/mean = 17.910715, loss = 77.687584, prediction/mean = 18.665035
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: tf_wx_model\model.ckpt-1200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 63.58948, step = 1200
# INFO:tensorflow:global_step/sec: 51.8672
# INFO:tensorflow:loss = 62.633442, step = 1300 (1.930 sec)
# INFO:tensorflow:global_step/sec: 60.2695
# INFO:tensorflow:loss = 61.815174, step = 1400 (1.659 sec)
# INFO:tensorflow:global_step/sec: 60.5682
# INFO:tensorflow:loss = 53.826015, step = 1500 (1.651 sec)
# INFO:tensorflow:Saving checkpoints for 1600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 51.28364.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:54
# INFO:tensorflow:Saving dict for global step 1600: average_loss = 60.830147, global_step = 1600, label/mean = 17.910715, loss = 60.830147, prediction/mean = 18.596676
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: tf_wx_model\model.ckpt-1600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:42:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:42:56
# INFO:tensorflow:Saving dict for global step 1600: average_loss = 60.830147, global_step = 1600, label/mean = 17.910715, loss = 60.830147, prediction/mean = 18.596676
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: tf_wx_model\model.ckpt-1600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 56.974346, step = 1600
# INFO:tensorflow:global_step/sec: 50.5108
# INFO:tensorflow:loss = 53.32673, step = 1700 (1.982 sec)
# INFO:tensorflow:global_step/sec: 59.9299
# INFO:tensorflow:loss = 43.931454, step = 1800 (1.668 sec)
# INFO:tensorflow:global_step/sec: 59.9626
# INFO:tensorflow:loss = 43.718956, step = 1900 (1.668 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into tf_wx_model\model.ckpt.
# WARNING:tensorflow:From C:\Users\Darak\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 44.006073.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:11
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 49.177387, global_step = 2000, label/mean = 17.910715, loss = 49.177387, prediction/mean = 18.547617
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: tf_wx_model\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:14
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 49.177387, global_step = 2000, label/mean = 17.910715, loss = 49.177387, prediction/mean = 18.547617
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: tf_wx_model\model.ckpt-2000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2000 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 39.762524, step = 2000
# INFO:tensorflow:global_step/sec: 51.391
# INFO:tensorflow:loss = 41.77836, step = 2100 (1.950 sec)
# INFO:tensorflow:global_step/sec: 57.9531
# INFO:tensorflow:loss = 43.197666, step = 2200 (1.727 sec)
# INFO:tensorflow:global_step/sec: 60.7358
# INFO:tensorflow:loss = 33.105522, step = 2300 (1.645 sec)
# INFO:tensorflow:Saving checkpoints for 2400 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 37.20605.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:29
# INFO:tensorflow:Saving dict for global step 2400: average_loss = 40.910732, global_step = 2400, label/mean = 17.910715, loss = 40.910732, prediction/mean = 18.495747
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2400: tf_wx_model\model.ckpt-2400
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:31
# INFO:tensorflow:Saving dict for global step 2400: average_loss = 40.910732, global_step = 2400, label/mean = 17.910715, loss = 40.910732, prediction/mean = 18.495747
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2400: tf_wx_model\model.ckpt-2400
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2400 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 36.430298, step = 2400
# INFO:tensorflow:global_step/sec: 50.8839
# INFO:tensorflow:loss = 34.22778, step = 2500 (1.986 sec)
# INFO:tensorflow:global_step/sec: 58.9798
# INFO:tensorflow:loss = 28.666344, step = 2600 (1.673 sec)
# INFO:tensorflow:global_step/sec: 59.5173
# INFO:tensorflow:loss = 28.697329, step = 2700 (1.681 sec)
# INFO:tensorflow:Saving checkpoints for 2800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 32.741917.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:47
# INFO:tensorflow:Saving dict for global step 2800: average_loss = 34.98509, global_step = 2800, label/mean = 17.910715, loss = 34.98509, prediction/mean = 18.446705
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: tf_wx_model\model.ckpt-2800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:43:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:43:49
# INFO:tensorflow:Saving dict for global step 2800: average_loss = 34.98509, global_step = 2800, label/mean = 17.910715, loss = 34.98509, prediction/mean = 18.446705
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: tf_wx_model\model.ckpt-2800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 28.738365, step = 2800
# INFO:tensorflow:global_step/sec: 52.1788
# INFO:tensorflow:loss = 30.129185, step = 2900 (1.917 sec)
# INFO:tensorflow:global_step/sec: 60.3747
# INFO:tensorflow:loss = 33.745316, step = 3000 (1.656 sec)
# INFO:tensorflow:global_step/sec: 61.1594
# INFO:tensorflow:loss = 25.818653, step = 3100 (1.635 sec)
# INFO:tensorflow:Saving checkpoints for 3200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 28.415554.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:05
# INFO:tensorflow:Saving dict for global step 3200: average_loss = 30.701067, global_step = 3200, label/mean = 17.910715, loss = 30.701067, prediction/mean = 18.422276
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3200: tf_wx_model\model.ckpt-3200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:06
# INFO:tensorflow:Saving dict for global step 3200: average_loss = 30.701067, global_step = 3200, label/mean = 17.910715, loss = 30.701067, prediction/mean = 18.422276
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3200: tf_wx_model\model.ckpt-3200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 26.381252, step = 3200
# INFO:tensorflow:global_step/sec: 48.7214
# INFO:tensorflow:loss = 30.619915, step = 3300 (2.053 sec)
# INFO:tensorflow:global_step/sec: 61.0928
# INFO:tensorflow:loss = 23.398176, step = 3400 (1.638 sec)
# INFO:tensorflow:global_step/sec: 58.7433
# INFO:tensorflow:loss = 26.503477, step = 3500 (1.702 sec)
# INFO:tensorflow:Saving checkpoints for 3600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 24.211329.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:22
# INFO:tensorflow:Saving dict for global step 3600: average_loss = 27.547695, global_step = 3600, label/mean = 17.910715, loss = 27.547695, prediction/mean = 18.391403
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3600: tf_wx_model\model.ckpt-3600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:24
# INFO:tensorflow:Saving dict for global step 3600: average_loss = 27.547695, global_step = 3600, label/mean = 17.910715, loss = 27.547695, prediction/mean = 18.391403
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3600: tf_wx_model\model.ckpt-3600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-3600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 27.804913, step = 3600
# INFO:tensorflow:global_step/sec: 48.583
# INFO:tensorflow:loss = 18.81324, step = 3700 (2.059 sec)
# INFO:tensorflow:global_step/sec: 56.7339
# INFO:tensorflow:loss = 21.61294, step = 3800 (1.762 sec)
# INFO:tensorflow:global_step/sec: 60.432
# INFO:tensorflow:loss = 22.709421, step = 3900 (1.656 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 25.17927.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:40
# INFO:tensorflow:Saving dict for global step 4000: average_loss = 25.206247, global_step = 4000, label/mean = 17.910715, loss = 25.206247, prediction/mean = 18.36312
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: tf_wx_model\model.ckpt-4000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T10:44:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-10:44:42
# INFO:tensorflow:Saving dict for global step 4000: average_loss = 25.206247, global_step = 4000, label/mean = 17.910715, loss = 25.206247, prediction/mean = 18.36312
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: tf_wx_model\model.ckpt-4000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4000 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 22.119995, step = 4000
# INFO:tensorflow:global_step/sec: 51.0801
# INFO:tensorflow:loss = 20.526558, step = 4100 (1.960 sec)
# INFO:tensorflow:global_step/sec: 58.8055
# INFO:tensorflow:loss = 23.104492, step = 4200 (1.700 sec)
# INFO:tensorflow:global_step/sec: 60.4033
# INFO:tensorflow:loss = 20.58692, step = 4300 (1.656 sec)
# INFO:tensorflow:Saving checkpoints for 4400 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 20.504038.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# ...
# INFO:tensorflow:global_step/sec: 61.3369
# INFO:tensorflow:loss = 11.103205, step = 38600 (1.630 sec)
# INFO:tensorflow:global_step/sec: 61.6023
# INFO:tensorflow:loss = 12.244329, step = 38700 (1.623 sec)
# INFO:tensorflow:Saving checkpoints for 38800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 11.361724.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-38800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:17
# INFO:tensorflow:Saving dict for global step 38800: average_loss = 12.602366, global_step = 38800, label/mean = 17.910715, loss = 12.602366, prediction/mean = 18.10758
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38800: tf_wx_model\model.ckpt-38800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-38800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:18
# INFO:tensorflow:Saving dict for global step 38800: average_loss = 12.602366, global_step = 38800, label/mean = 17.910715, loss = 12.602366, prediction/mean = 18.10758
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 38800: tf_wx_model\model.ckpt-38800
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-38800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 38800 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 13.098697, step = 38800
# INFO:tensorflow:global_step/sec: 52.2739
# INFO:tensorflow:loss = 13.095909, step = 38900 (1.917 sec)
# INFO:tensorflow:global_step/sec: 60.2703
# INFO:tensorflow:loss = 12.508611, step = 39000 (1.659 sec)
# INFO:tensorflow:global_step/sec: 59.4716
# INFO:tensorflow:loss = 11.561568, step = 39100 (1.681 sec)
# INFO:tensorflow:Saving checkpoints for 39200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 12.129282.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:35
# INFO:tensorflow:Saving dict for global step 39200: average_loss = 12.554699, global_step = 39200, label/mean = 17.910715, loss = 12.554699, prediction/mean = 18.115833
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39200: tf_wx_model\model.ckpt-39200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:37
# INFO:tensorflow:Saving dict for global step 39200: average_loss = 12.554699, global_step = 39200, label/mean = 17.910715, loss = 12.554699, prediction/mean = 18.115833
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39200: tf_wx_model\model.ckpt-39200
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 39200 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 13.810491, step = 39200
# INFO:tensorflow:global_step/sec: 51.9795
# INFO:tensorflow:loss = 14.180205, step = 39300 (1.928 sec)
# INFO:tensorflow:global_step/sec: 57.3014
# INFO:tensorflow:loss = 12.453674, step = 39400 (1.745 sec)
# INFO:tensorflow:global_step/sec: 61.2617
# INFO:tensorflow:loss = 13.169934, step = 39500 (1.632 sec)
# INFO:tensorflow:Saving checkpoints for 39600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 11.974308.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:52
# INFO:tensorflow:Saving dict for global step 39600: average_loss = 12.492638, global_step = 39600, label/mean = 17.910715, loss = 12.492638, prediction/mean = 18.086283
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39600: tf_wx_model\model.ckpt-39600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:11:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:11:54
# INFO:tensorflow:Saving dict for global step 39600: average_loss = 12.492638, global_step = 39600, label/mean = 17.910715, loss = 12.492638, prediction/mean = 18.086283
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39600: tf_wx_model\model.ckpt-39600
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-39600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 39600 into tf_wx_model\model.ckpt.
# INFO:tensorflow:loss = 13.857466, step = 39600
# INFO:tensorflow:global_step/sec: 50.7058
# INFO:tensorflow:loss = 11.327336, step = 39700 (1.976 sec)
# INFO:tensorflow:global_step/sec: 58.2558
# INFO:tensorflow:loss = 12.015873, step = 39800 (1.716 sec)
# INFO:tensorflow:global_step/sec: 61.5642
# INFO:tensorflow:loss = 13.03385, step = 39900 (1.624 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into tf_wx_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 12.214869.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:12:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:12:09
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 12.4467945, global_step = 40000, label/mean = 17.910715, loss = 12.4467945, prediction/mean = 18.08819
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: tf_wx_model\model.ckpt-40000
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-04-19T11:12:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-04-19-11:12:10
# INFO:tensorflow:Saving dict for global step 40000: average_loss = 12.4467945, global_step = 40000, label/mean = 17.910715, loss = 12.4467945, prediction/mean = 18.08819
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40000: tf_wx_model\model.ckpt-40000

# %%
evaluations[0]
# Out:
# {'average_loss': 139.82773,
#  'label/mean': 17.910715,
#  'loss': 139.82773,
#  'prediction/mean': 18.828098,
#  'global_step': 400}

# %%
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# manually set the parameters of the figure to and appropriate size
plt.rcParams['figure.figsize'] = [14, 10]

loss_values = [ev['loss'] for ev in evaluations]
training_steps = [ev['global_step'] for ev in evaluations]

plt.scatter(x=training_steps, y=loss_values)
plt.xlabel('Training steps (Epochs = steps / 2)')
plt.ylabel('Loss (SSE)')
plt.show()

# %%
pred = regressor.predict(input_fn=wx_input_fn(X_test,
                                              num_epochs=1,
                                              shuffle=False))
predictions = np.array([p['predictions'][0] for p in pred])

print("The Explained Variance: %.2f" % explained_variance_score(
                                            y_test, predictions))  
print("The Mean Absolute Error: %.2f degrees Celcius" % mean_absolute_error(
                                            y_test, predictions))  
print("The Median Absolute Error: %.2f degrees Celcius" % median_absolute_error(
                                            y_test, predictions))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_wx_model\model.ckpt-40000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# The Explained Variance: 0.89
# The Mean Absolute Error: 3.05 degrees Celcius
# The Median Absolute Error: 2.76 degrees Celcius
